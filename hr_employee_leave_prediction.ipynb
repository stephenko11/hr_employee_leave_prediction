# %% [markdown]
# # **Capstone project: Providing data-driven suggestions for HR**

# %% [markdown]
# ## Description and deliverables
#
# This capstone project is an opportunity for you to analyze a dataset and build predictive models that can provide insights to the Human Resources (HR) department of a large consulting firm.
#
# Upon completion, you will have two artifacts that you would be able to present to future employers. One is a brief one-page summary of this project that you would present to external stakeholders as the data professional in Salifort Motors. The other is a complete code notebook provided here. Please consider your prior course work and select one way to achieve this given project question. Either use a regression model or machine learning model to predict whether or not an employee will leave the company. The exemplar following this actiivty shows both approaches, but you only need to do one.
#
# In your deliverables, you will include the model evaluation (and interpretation if applicable), a data visualization(s) of your choice that is directly related to the question you ask, ethical considerations, and the resources you used to troubleshoot and find answers or solutions.

# %% [markdown]
# # **PACE stages**

# %% [markdown]
# ![Screenshot 2022-08-04 5.47.37 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## **Pace: Plan**
#
# Consider the questions in your PACE Strategy Document to reflect on the Plan stage.
#
# In this stage, consider the following:

# %% [markdown]
# ### Understand the business scenario and problem
#
# The HR department at Salifort Motors wants to take some initiatives to improve employee satisfaction levels at the company. They collected data from employees, but now they don’t know what to do with it. They refer to you as a data analytics professional and ask you to provide data-driven suggestions based on your understanding of the data. They have the following question: what’s likely to make the employee leave the company?
#
# Your goals in this project are to analyze the data collected by the HR department and to build a model that predicts whether or not an employee will leave the company.
#
# If you can predict employees likely to quit, it might be possible to identify factors that contribute to their leaving. Because it is time-consuming and expensive to find, interview, and hire new employees, increasing employee retention will be beneficial to the company.

# %% [markdown]
# ### Familiarize yourself with the HR dataset
#
# The dataset that you'll be using in this lab contains 15,000 rows and 10 columns for the variables listed below.
#
# **Note:** you don't need to download any data to complete this lab. For more information about the data, refer to its source on [Kaggle](https://www.kaggle.com/datasets/mfaisalqureshi/hr-analytics-and-job-prediction?select=HR_comma_sep.csv).
#
# Variable  |Description |
# -----|-----|
# satisfaction_level|Employee-reported job satisfaction level [0&ndash;1]|
# last_evaluation|Score of employee's last performance review [0&ndash;1]|
# number_project|Number of projects employee contributes to|
# average_monthly_hours|Average number of hours employee worked per month|
# time_spend_company|How long the employee has been with the company (years)
# Work_accident|Whether or not the employee experienced an accident while at work
# left|Whether or not the employee left the company
# promotion_last_5years|Whether or not the employee was promoted in the last 5 years
# Department|The employee's department
# salary|The employee's salary (U.S. dollars)

# %% [markdown]
# 💭
# ### Reflect on these questions as you complete the plan stage.
#
# *  Who are your stakeholders for this project?
# - What are you trying to solve or accomplish?
# - What are your initial observations when you explore the data?
# - What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# - Do you have any ethical considerations in this stage?

# %% [markdown]
# The HR department and the senior management are the stakeholders for this project. We are trying to discover the a classification model to predict whether the employee is likely to leave the company.

# %% [markdown]
# ## Step 1. Imports
#
# *   Import packages
# *   Load dataset

# %% [markdown]
# ### Import packages

# %%
# Import packages
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics

# %% [markdown]
# ### Load dataset
#
# `Pandas` is used to read a dataset called **`HR_capstone_dataset.csv`.**  As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# RUN THIS CELL TO IMPORT YOUR DATA. 

# Load dataset into a dataframe
### YOUR CODE HERE ###
df0 = pd.read_csv("HR_capstone_dataset.csv")


# Display first few rows of the dataframe
df0.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %% [markdown]
# ## Step 2. Data Exploration (Initial EDA and data cleaning)
#
# - Understand your variables
# - Clean your dataset (missing data, redundant data, outliers)

# %% [markdown]
# ### Gather basic information about the data

# %%
# Gather basic information about the data
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Gather descriptive statistics about the data

# %%
# Gather descriptive statistics about the data
df0.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %% [markdown]
# ### Rename columns

# %% [markdown]
# As a data cleaning step, rename the columns as needed. Standardize the column names so that they are all in `snake_case`, correct any column names that are misspelled, and make column names more concise as needed.

# %%
# Display all column names
df0.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
# Rename columns as needed
df0 = df0.rename(columns={'average_montly_hours':'average_monthly_hours', 
                          'time_spend_company':'year_with_company', 
                          'Work_accident':'work_accident', 
                          'Department':'department'})


# Display all column names after the update
df0.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_monthly_hours', 'year_with_company', 'work_accident', 'left',
#        'promotion_last_5years', 'department', 'salary'],
#       dtype='object')

# %% [markdown]
# ### Check missing values

# %% [markdown]
# Check for any missing values in the data.

# %%
# Check for missing values
df0.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_monthly_hours    0
# year_with_company        0
# work_accident            0
# left                     0
# promotion_last_5years    0
# department               0
# salary                   0
# dtype: int64

# %% [markdown]
# ### Check duplicates

# %% [markdown]
# Check for any duplicate entries in the data.

# %%
# Check for duplicates
df0.duplicated().sum()
# Out:
# 3008

# %%
# Inspect some rows containing duplicates as needed
df0[df0.duplicated()]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 396                  0.46             0.57               2
# 866                  0.41             0.46               2
# 1317                 0.37             0.51               2
# 1368                 0.41             0.52               2
# 1461                 0.42             0.53               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_monthly_hours  year_with_company  work_accident  left  \
# 396                      139                  3              0     1
# 866                      128                  3              0     1
# ...

# %%
# Drop duplicates and save resulting dataframe in a new variable as needed
df1 = df0.drop_duplicates()


# Display first few rows of new dataframe as needed
df1.head(5)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_monthly_hours  \
# 0                0.38             0.53               2                    157
# 1                0.80             0.86               5                    262
# 2                0.11             0.88               7                    272
# 3                0.72             0.87               5                    223
# 4                0.37             0.52               2                    159
#
#    year_with_company  work_accident  left  promotion_last_5years department  \
# 0                  3              0     1                      0      sales
# 1                  6              0     1                      0      sales
# 2                  4              0     1                      0      sales
# 3                  5              0     1                      0      sales
# 4                  3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %% [markdown]
# ### Check outliers

# %% [markdown]
# Check for outliers in the data.

# %%
df1.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_monthly_hours', 'year_with_company', 'work_accident', 'left',
#        'promotion_last_5years', 'department', 'salary'],
#       dtype='object')

# %%
# Create a boxplot to visualize distribution of `tenure` and detect any outliers
boxplot_to_plot = ['number_project','average_monthly_hours','year_with_company']

# Box plot all the numerical variables to detect outliers
fig, axs = plt.subplots(len(boxplot_to_plot), figsize=(20, 10))

for i, each_plot_name in enumerate(boxplot_to_plot):
    name = df1[each_plot_name].name
    sns.boxplot(data=df1, x=each_plot_name, ax=axs[i]).set(xlabel=f'{name}', title=f'boxplot to detect outliers of {name}')
    
fig.subplots_adjust(hspace=0.5)

# %%
# Determine the number of rows containing outliers
upper_75_percentile = df1['year_with_company'].quantile(0.75)
lower_25_percentile = df1['year_with_company'].quantile(0.25)
iqr = upper_75_percentile - lower_25_percentile
upper_limit = upper_75_percentile + 1.5*iqr

df1[df1['year_with_company'] > upper_limit]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 1                    0.80             0.86               5
# 17                   0.78             0.99               4
# 34                   0.84             0.87               4
# 47                   0.57             0.70               3
# 67                   0.90             0.98               4
# ...                   ...              ...             ...
# 11994                0.22             0.94               3
# 11995                0.90             0.55               3
# 11996                0.74             0.95               5
# 11997                0.85             0.54               3
# 11998                0.33             0.65               3
#
#        average_monthly_hours  year_with_company  work_accident  left  \
# 1                        262                  6              0     1
# 17                       255                  6              0     1
# ...

# %% [markdown]
# Certain types of models are more sensitive to outliers than others. When you get to the stage of building your model, consider whether to remove outliers, based on the type of model you decide to use.

# %% [markdown]
# # pAce: Analyze Stage
# - Perform EDA (analyze relationships between variables)

# %% [markdown]
# 💭
# ### Reflect on these questions as you complete the analyze stage.
#
# - What did you observe about the relationships between variables?
# - What do you observe about the distributions in the data?
# - What transformations did you make with your data? Why did you chose to make those decisions?
# - What are some purposes of EDA before constructing a predictive model?
# - What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# - Do you have any ethical considerations in this stage?

# %% [markdown]
# ## Step 2. Data Exploration (Continue EDA)
#
# Begin by understanding how many employees left and what percentage of all employees this figure represents.

# %%
# Get numbers of people who left vs. stayed
df1['left'].value_counts()

# Get percentages of people who left vs. stayed
df1['left'].value_counts(normalize=True)
# Out:
# 0    0.833959
# 1    0.166041
# Name: left, dtype: float64

# %% [markdown]
# ### Data visualizations

# %% [markdown]
# Now, examine variables that you're interested in, and create plots to visualize relationships between variables in the data.

# %% [markdown]
# Create pair plots to have an overview visualization of the relationships among the variables

# %%
sns.pairplot(data=df1, hue='left')

# %% [markdown]
# It is natural that people who have lower satisfaction levels are more likely to leave the company. People who work longer hours are more likely to have a lower satisfaction level. Therefore, we would like to first investigate the relationship among satisfaction level, average monthly hour and the employee who stayed.

# %%
# Create a plot as needed
fig, ax = plt.subplots(figsize=(20, 10))
sns.set(font_scale=2)
sns.scatterplot(data=df1, y='satisfaction_level', x='average_monthly_hours', hue='left').set(title='Satisfaction Level by Average Monthly Hour', 
                                                                                       xlabel='Average Monthly Hours', 
                                                                                       ylabel='Satisfaction Level')
# Out:
# [Text(0, 0.5, 'Satisfaction Level'),
#  Text(0.5, 0, 'Average Monthly Hours'),
#  Text(0.5, 1.0, 'Satisfaction Level by Average Monthly Hour')]

# %% [markdown]
# The preceding sattered plot depicts that there are two major groups of non-retained employees.
#
# The first group is those who worked over around 240 hours per month and had almost zero satisfaction level.
#
# The second gorup is those who worked between arond 130 and 160 hours and had satisfaction level between 0.3 and 0.5.
#
# It is natural that people who work on more projects would also have longer working hours. We then investigate the relationhsip between the working hours and the number of projects.

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(data=df1, y='average_monthly_hours', x='number_project', hue='left', ax=ax[0]).set(
                                                                                       xlabel='Number of Project', 
                                                                                       ylabel='Average Monthly Hours')
ax[0].set_title('Average Monthly Working Hours by Number of Project', fontsize=20)



sns.histplot(data=df1, x='number_project', hue='left', multiple='dodge', ax=ax[1]).set(
                                                                          xlabel='Number of Project', 
                                                                          ylabel='Count')

ax[1].set_title('Distribution of Number of Project', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of Number of Project')

# %% [markdown]
# The preceding plot depicts that the mean of the average monthly hours of the non-retained employees is higher than the mean of the average montly hours of the retained employees given the same number of project except for when they were given 2 or 7 projects. The mean of the average monthly hours of the non-retained employees who received 2 projects is lower than the mean of the average monthly hours of the retained employees given the same number of project. All the employees left when they were given 7 projects.
#
# The number of projects and the average monthly hours could be a good predictive variables for the model.
#
# Next, we can investigate the relationship among number of project, evaluation and retention.

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(data=df1, y='last_evaluation', x='number_project', hue='left', ax=ax[0]).set(
                                                                                       xlabel='Number of Project', 
                                                                                       ylabel='Last Evaluation')
ax[0].set_title('Average Monthly Working Hours by Number of Project', fontsize=20)



sns.histplot(data=df1, x='number_project', hue='left', multiple='dodge', ax=ax[1]).set(
                                                                          xlabel='Number of Project', 
                                                                          ylabel='Count')

ax[1].set_title('Distribution of Number of Project', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of Number of Project')

# %% [markdown]
# The mean of last evaluation of the non-retained employees is higher than the mean of the last evaluation of the retained employees given the same number of project except for when they were given 2 or 7 projects. The mean of the last evaluation of the non-retained employees who received 2 projects is lower than the mean of the last evaluation of the retained employees given the same number of project. All the employees left when they were given 7 projects.
#
# It seems that the non-retained employees tend to work longer hours and have higher evaluation score except when they were given 2 or 7 projects.
#
# Next, we investigate the relationship among tenure, satisfaction and retention

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(data=df1, y='satisfaction_level', x='year_with_company', hue='left', ax=ax[0]).set(
                                                                                       xlabel='Tenure', 
                                                                                       ylabel='Satisfaction')
ax[0].set_title('Satisfaction Level by Tenure', fontsize=20)



sns.histplot(data=df1, x='year_with_company', hue='left', multiple='dodge', shrink=3, ax=ax[1]).set(
                                                                          xlabel='Tenure', 
                                                                          ylabel='Count')

ax[1].set_title('Distribution of Tenure', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of Tenure')

# %% [markdown]
# There are two groups of non-retained employees. The first group is the dissatisfied employees who worked less than 5 years. The second group is the satisfied employees who worked for 5 to 6 years. employees who worked in this company for more than 7 years tends to stay with the company.

# %%
df1.groupby('left')['satisfaction_level'].agg(['mean', 'median'])
# Out:
#           mean  median
# left
# 0     0.667365    0.69
# 1     0.440271    0.41

# %% [markdown]
# It is noted that the average and median of the satisfaction level for employees who left are lower than the employees who stayed.
#
# Next, we examine the relationship between salary satisfaction level

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(data=df1, y='satisfaction_level', x='salary', hue='left', ax=ax[0]).set(
                                                                                    xlabel='Salary Level', 
                                                                                    ylabel='Satisfaction')
ax[0].set_title('Satisfaction by Salary Level', fontsize=20)



sns.histplot(data=df1, x='salary', hue='left', multiple='dodge', ax=ax[1]).set(
                                                                          xlabel='Salary Level', 
                                                                          ylabel='Count')

ax[1].set_title('Distribution of Salary Level', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of Salary Level')

# %% [markdown]
# The satisfaction level of employees who left are lower than the satisfaction elvel of employees who stayed across all salary level.
#
# Next, we examine the satifaction level across departments

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
sns.boxplot(data=df1, y='satisfaction_level', x='department', hue='left', ax=ax[0]).set(
                                                                                    xlabel='Department', 
                                                                                    ylabel='Satisfaction')
ax[0].set_title('Satisfaction by Department', fontsize=20)
ax[0].tick_params(axis='x', rotation=90)



sns.histplot(data=df1, x='department', hue='left', multiple='dodge', ax=ax[1]).set(
                                                                          xlabel='Department', 
                                                                          ylabel='Count')

ax[1].set_title('Distribution of Employee Who Left By Department', fontsize=20)
ax[1].tick_params(axis='x', rotation=90)

# %% [markdown]
# There is no significant difference in the satisfication level between the employees who left and employees who stayed across the departments. There is also no significant difference in the proportion between the number of  employees who left and the number of employees who stayed across the departments.
#
# Next, we exmaine the relationship between the working hours and promotion within last 5 years.

# %%
# Create a plot as needed
fig, ax = plt.subplots(figsize=(20, 10))

sns.scatterplot(data=df1, y='promotion_last_5years', x='average_monthly_hours', hue='left')

# %% [markdown]
# Employees who worked around 300 monthly hour without promotion tends to leave the company.
# The employees who worked long hours were often not promoted
# Very few employees who got promoted in the last 5 years left.

# %%
# Create a plot as needed
# Plot a correlation heatmap
plt.figure(figsize=(16, 9))
heatmap = sns.heatmap(df1.corr(), vmin=-1, vmax=1, annot=True, cmap=sns.color_palette("vlag", as_cmap=True))
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':14}, pad=12);

# %% [markdown]
# ### Insights

# %% [markdown]
# For the preceding plots, satisfaction, number of projects, average working hours and evaluation are good predictors to predict whether an employee will leave the company. Overworked employee tends to leave the compnay. Employee who received promotion within the last 5 years was less likely to leave. Further, employee who worked in the company for more than 6 years was less likely to leave.

# %% [markdown]
# # paCe: Construct Stage
# - Determine which models are most appropriate
# - Construct the model
# - Confirm model assumptions
# - Evaluate model results to determine how well your model fits the data

# %% [markdown]
# 🔎
# ## Recall model assumptions
#
# **Logistic Regression model assumptions**
# - Outcome variable is categorical
# - Observations are independent of each other
# - No severe multicollinearity among X variables
# - No extreme outliers
# - Linear relationship between each X variable and the logit of the outcome variable
# - Sufficiently large sample size

# %% [markdown]
# 💭
# ### Reflect on these questions as you complete the constructing stage.
#
# - Do you notice anything odd?
# - Which independent variables did you choose for the model and why?
# - Are each of the assumptions met?
# - How well does your model fit the data?
# - Can you improve it? Is there anything you would change about the model?
# - What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# - Do you have any ethical considerations in this stage?

# %% [markdown]
# ## Step 3. Model Building, Step 4. Results and Evaluation
# - Fit a model that predicts the outcome variable using two or more independent variables
# - Check model assumptions
# - Evaluate the model

# %% [markdown]
# ### Identify the type of prediction task.

# %% [markdown]
# It is a binary prediction task

# %% [markdown]
# ### Identify the types of models most appropriate for this task.

# %% [markdown]
# I will build a random forest and a XGBoost models, compare their predictive power and error, and

# %% [markdown]
# ### Modeling
#
# Add as many cells as you need to conduct the modeling process.

# %%
### YOUR CODE HERE ###
# import libaries
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

from xgboost import XGBClassifier
from xgboost import plot_importance

import pickle

import matplotlib

# %% [markdown]
# Encoding categorical variables

# %%
#Encode Variables
df1_subset = pd.get_dummies(df1, drop_first=True)
df1_subset
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 11995                0.90             0.55               3
# 11996                0.74             0.95               5
# 11997                0.85             0.54               3
# 11998                0.33             0.65               3
# 11999                0.50             0.73               4
#
#        average_monthly_hours  year_with_company  work_accident  left  \
# 0                        157                  3              0     1
# 1                        262                  6              0     1
# ...

# %%
y=df1_subset['left']
X=df1_subset.drop('left', axis=1)

# %% [markdown]
# Separate variables into train, validate and test sets

# %%
# Separate into train, validate, test sets.

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    stratify=y,
                                                    random_state = 0)

X_tr, X_val, y_tr, y_val = train_test_split(X_train, 
                                            y_train, 
                                            test_size = 0.25, 
                                            random_state = 0)

# %% [markdown]
# # XGBoost

# %%
xgb = XGBClassifier(objective='binary:logistic', random_state=0)

# %% [markdown]
# Setting up variables for grid search on the XGBoost model

# %%
# Grid Search
cv_params = {'max_depth': [4, 6],
              'min_child_weight': [3, 5],
              'learning_rate': [0.1, 0.2, 0.3],
              'n_estimators': [100,300],
              'subsample': [0.3, 0.5],
              'colsample_bytree': [0.5, 0.7]
              }

scoring = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

# %%
xgb_val = GridSearchCV(xgb, 
                   cv_params,
                   scoring=scoring, 
                   cv=5, 
                   refit="f1")

# %%
# %%time
xgb_cv = xgb_val.fit(X_train, y_train)
# Out:
# CPU times: user 14min 21s, sys: 4.87 s, total: 14min 26s
# Wall time: 7min 16s

# %% [markdown]
# Display the parameters of the best model

# %%
xgb_cv.best_params_
# Out:
# {'colsample_bytree': 0.5,
#  'learning_rate': 0.1,
#  'max_depth': 6,
#  'min_child_weight': 3,
#  'n_estimators': 100,
#  'subsample': 0.5}

# %% [markdown]
# Display the score of the best model

# %%
xgb_cv.best_score_
# Out:
# 0.9812075797887962

# %% [markdown]
# defining helper function to save and load the gridsearch result

# %%
def write_pickle(path, model_object, save_as:str):
    '''
    In: 
        path:         path of folder where you want to save the pickle
        model_object: a model you want to pickle
        save_as:      filename for how you want to save the model

    Out: A call to pickle the model in the folder indicated
    '''    

    with open(path + save_as + '.pickle', 'wb') as to_write:
        pickle.dump(model_object, to_write)

# %%
def read_pickle(path, saved_model_name:str):
    '''
    In: 
        path:             path to folder where you want to read from
        saved_model_name: filename of pickled model you want to read in

    Out: 
        model: the pickled model 
    '''
    with open(path + saved_model_name + '.pickle', 'rb') as to_read:
        model = pickle.load(to_read)

    return model

# %% [markdown]
# Saving and loading the gridsearch result using the pickle helper function

# %%
path = '/home/jovyan/work/'

# Write pickle
write_pickle(path, xgb_cv, 'xgb_cv')

# %%
# Read pickle
xgb_cv = read_pickle(path, 'xgb_cv')

# %% [markdown]
# Validating the model using validating dataset

# %%
y_val_pred = xgb_cv.best_estimator_.predict(X_val)

# %%
# 1. Print your accuracy score.

### YOUR CODE HERE ###
ac_score = metrics.accuracy_score(y_val, y_val_pred)
print('accuracy score:', ac_score)

# 2. Print your precision score.

### YOUR CODE HERE ###
pc_score = metrics.precision_score(y_val, y_val_pred)
print('precision score:', pc_score)

# 3. Print your recall score.

### YOUR CODE HERE ###
rc_score = metrics.recall_score(y_val, y_val_pred)
print('recall score:', rc_score)

# 4. Print your f1 score.

### YOUR CODE HERE ###
f1_score = metrics.f1_score(y_val, y_val_pred)
print('f1 score:', f1_score)

# 5. Print your AUC score
auc_score = metrics.roc_auc_score(y_val, y_val_pred)
print('AUC score:', auc_score)
# Out:
# accuracy score: 0.9835482436638506
# precision score: 0.9942196531791907
# recall score: 0.9076517150395779
# f1 score: 0.9489655172413792
# AUC score: 0.9532910981615001

# %% [markdown]
# Plotting confusion Matrix

# %%
matplotlib.rc_file_defaults()
cm = metrics.confusion_matrix(y_val, y_val_pred, labels = xgb_cv.classes_)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = xgb_cv.classes_)
disp.plot()

# %% [markdown]
# The upper left quadrant displays the number of true negatives. The bottom right quadrant displays the number of true positives.
#
# The bottom left quadrant displays the number of false negatives and the upper right quadrant displays the number of false positives.
#
#
# True negatives:
# the number of employees who did not leave the company that the model accurately predicted did not leave.
#
# True postives:
# the number of employees who did leave the company that the model accurately predicted as leaving.
#
# False negatives:
# the number of employees who did leave the company that the model inaccurately predicted did not leave.
#
# false positives:
# the number of employees who did not leave the company that the model inaccurately predicted as leaving.

# %% [markdown]
# # Random Forest

# %% [markdown]
# Setting up variables for grid search on the Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
cv_params_rf = {'n_estimators' : [100,300], 
              'max_depth' : [4,6],        
              'min_samples_leaf' : [3, 5], 
              'min_samples_split' : [6, 10],
              'max_features' : [0.5, 0.7], 
              'max_samples' : [.5,.7]}

# Assign a dictionary of scoring metrics to capture
scoring_rf = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

rf = RandomForestClassifier(random_state = 0)

# Instantiate GridSearch
rf_val = GridSearchCV(rf, cv_params_rf, scoring=scoring_rf, cv=5, refit='f1')

# %%
# %%time
rf_cv = rf_val.fit(X_train, y_train)
# Out:
# CPU times: user 4min 42s, sys: 698 ms, total: 4min 43s
# Wall time: 4min 43s

# %% [markdown]
# Displaying the parameters of the best random forest model from the gridsearch

# %%
rf_cv.best_params_
# Out:
# {'max_depth': 6,
#  'max_features': 0.7,
#  'max_samples': 0.7,
#  'min_samples_leaf': 3,
#  'min_samples_split': 6,
#  'n_estimators': 100}

# %% [markdown]
# Displaying the score of the best random forest model from the gridsearch

# %%
rf_cv.best_score_
# Out:
# 0.9409578317254776

# %% [markdown]
# Saving and loading the gridsearhc model

# %%
path = '/home/jovyan/work/'

# Write pickle
write_pickle(path, rf_cv, 'rf_cv')

# %%
# Read pickle
rf_cv = read_pickle(path, 'rf_cv')

# %% [markdown]
# Validating the random forest model using the validation dataset

# %%
y_val_pred_rf = rf_cv.best_estimator_.predict(X_val)

# %%
# 1. Print your accuracy score.

### YOUR CODE HERE ###
ac_score_rf = metrics.accuracy_score(y_val, y_val_pred_rf)
print('accuracy score:', ac_score_rf)

# 2. Print your precision score.

### YOUR CODE HERE ###
pc_score_rf = metrics.precision_score(y_val, y_val_pred_rf)
print('precision score:', pc_score_rf)

# 3. Print your recall score.

### YOUR CODE HERE ###
rc_score_rf = metrics.recall_score(y_val, y_val_pred_rf)
print('recall score:', rc_score_rf)

# 4. Print your f1 score.

### YOUR CODE HERE ###
f1_score_rf = metrics.f1_score(y_val, y_val_pred_rf)
print('f1 score:', f1_score_rf)

# 5. Print your AUC score
auc_score_rf = metrics.roc_auc_score(y_val, y_val_pred_rf)
print('AUC score:', auc_score_rf)
# Out:
# accuracy score: 0.9813250333481547
# precision score: 0.9884057971014493
# recall score: 0.899736147757256
# f1 score: 0.9419889502762432
# AUC score: 0.9487985551620505

# %% [markdown]
# Plotting confusion matrix

# %%
matplotlib.rc_file_defaults()
cm = metrics.confusion_matrix(y_val, y_val_pred_rf, labels = rf_cv.classes_)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = rf_cv.classes_)
disp.plot()

# %% [markdown]
# The upper left quadrant displays the number of true negatives. The bottom right quadrant displays the number of true positives.
#
# The bottom left quadrant displays the number of false negatives and the upper right quadrant displays the number of false positives.
#
#
# True negatives:
# the number of employees who did not leave the company that the model accurately predicted did not leave.
#
# True postives:
# the number of employees who did leave the company that the model accurately predicted as leaving.
#
# False negatives:
# the number of employees who did leave the company that the model inaccurately predicted did not leave.
#
# false positives:
# the number of employees who did not leave the company that the model inaccurately predicted as leaving.

# %% [markdown]
# Create a helper function to return a table with the F1, recall, precision, accuracy, and auc scores
#     for the model with the best mean 'metric' score across all validation folds

# %%
def make_results(model_name:str, model_object, metric:str):
    '''
    Arguments:
        model_name (string): what you want the model to be called in the output table
        model_object: a fit GridSearchCV object
        metric (string): precision, recall, f1, accuracy, or auc
  
    Returns a pandas df with the F1, recall, precision, accuracy, and auc scores
    for the model with the best mean 'metric' score across all validation folds.  
    '''

    # Create dictionary that maps input metric to actual metric name in GridSearchCV
    metric_dict = {'auc': 'mean_test_roc_auc',
                   'precision': 'mean_test_precision',
                   'recall': 'mean_test_recall',
                   'f1': 'mean_test_f1',
                   'accuracy': 'mean_test_accuracy'
                  }

    # Get all the results from the CV and put them in a df
    cv_results = pd.DataFrame(model_object.cv_results_)

    # Isolate the row of the df with the max(metric) score
    best_estimator_results = cv_results.iloc[cv_results[metric_dict[metric]].idxmax(), :]

    # Extract Accuracy, precision, recall, and f1 score from that row
    auc = best_estimator_results.mean_test_roc_auc
    f1 = best_estimator_results.mean_test_f1
    recall = best_estimator_results.mean_test_recall
    precision = best_estimator_results.mean_test_precision
    accuracy = best_estimator_results.mean_test_accuracy
  
    # Create table of results
    table = pd.DataFrame()
    table = pd.DataFrame({'model': [model_name],
                          'precision': [precision],
                          'recall': [recall],
                          'F1': [f1],
                          'accuracy': [accuracy],
                          'auc': [auc]
                        })
  
    return table

# %%
# Get all CV scores
rf_results = make_results('Random Forest', rf_cv, 'auc')
rf_results
# Out:
#               model  precision   recall        F1  accuracy       auc
# 0  decision tree cv   0.976243  0.90824  0.940958  0.981096  0.981293

# %% [markdown]
# Obtaining feature importances table and plot

# %%
rf_importances = pd.DataFrame(rf_cv.best_estimator_.feature_importances_, 
                                 columns=['importance'], 
                                 index=X.columns
                                )
rf_importances = rf_importances.sort_values(by='importance', ascending=False)

rf_importances
# Out:
#                         importance
# satisfaction_level        0.456758
# number_project            0.175718
# year_with_company         0.139427
# average_monthly_hours     0.113041
# last_evaluation           0.112451
# salary_low                0.000517
# department_technical      0.000355
# salary_medium             0.000290
# work_accident             0.000243
# department_accounting     0.000240
# department_support        0.000240
# department_sales          0.000208
# department_RandD          0.000164
# department_hr             0.000132
# department_marketing      0.000096
# department_product_mng    0.000060
# promotion_last_5years     0.000044
# department_management     0.000014

# %%
sns.barplot(data=rf_importances, y=rf_importances.index, x='importance', orient='h')

# %% [markdown]
# Satisfaction leve, number of project, tenure, average monthly hours and last evaluation have the highest importance, in that order. These variables are most helpful in predicting whether the employee would leave the company.

# %% [markdown]
# # Comparing XGBoost and Random Forest

# %%
score_comparison_table = pd.DataFrame({'model': ['XGBooster', 'Random Forest'],
                      'precision': [pc_score, pc_score_rf],
                       'recall': [rc_score, rc_score_rf],
                        'F1': [f1_score, f1_score_rf],
                        'accuracy': [ac_score, ac_score_rf],
                        'auc': [auc_score, auc_score_rf]
                        })
score_comparison_table
# Out:
#            model  precision    recall        F1  accuracy       auc
# 0      XGBooster   0.994220  0.907652  0.948966  0.983548  0.953291
# 1  Random Forest   0.988406  0.899736  0.941989  0.981325  0.948799

# %% [markdown]
# Both XGBoost model and the random forest model have good scores, indicating both of the model have a very good predictive power. XGBoost model is slightly better in every score. XGBoost model is selected and further evaluated using the test data.

# %% [markdown]
# # Evaluate Using Test Data

# %% [markdown]
# Validating the XG Boost model (the winning model) using the test dataset

# %%
y_pred = xgb_cv.best_estimator_.predict(X_test)

# %% [markdown]
# Evaluating the XG Boost model using the test dataset. Obtiaing its Accuracy, precision, recall, F1 score

# %%
# 1. Print your accuracy score.

### YOUR CODE HERE ###
ac_score = metrics.accuracy_score(y_test, y_pred)
print('accuracy score:', ac_score)

# 2. Print your precision score.

### YOUR CODE HERE ###
pc_score = metrics.precision_score(y_test, y_pred)
print('precision score:', pc_score)

# 3. Print your recall score.

### YOUR CODE HERE ###
rc_score = metrics.recall_score(y_test, y_pred)
print('recall score:', rc_score)

# 4. Print your f1 score.

### YOUR CODE HERE ###
f1_score = metrics.f1_score(y_test, y_pred)
print('f1 score:', f1_score)
# Out:
# accuracy score: 0.980653769179453
# precision score: 0.9721030042918455
# recall score: 0.9096385542168675
# f1 score: 0.9398340248962656

# %% [markdown]
# Plotting confusion maxtrix

# %%
cm = metrics.confusion_matrix(y_test, y_pred, labels = xgb_cv.classes_)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = xgb_cv.classes_)
disp.plot()

# %% [markdown]
# The upper left quadrant displays the number of true negatives. The bottom right quadrant displays the number of true positives.
#
# The bottom left quadrant displays the number of false negatives and the upper right quadrant displays the number of false positives.
#
#
# True negatives:
# the number of employees who did not leave the company that the model accurately predicted did not leave.
#
# True postives:
# the number of employees who did leave the company that the model accurately predicted as leaving.
#
# False negatives:
# the number of employees who did leave the company that the model inaccurately predicted did not leave.
#
# false positives:
# the number of employees who did not leave the company that the model inaccurately predicted as leaving.

# %%
plot_importance(xgb_cv.best_estimator_)

# %% [markdown]
# Last evaluation, average monthly hours, satisfaction level, tenure, number of projects and salary are the important features, in that order. They are important variables to predict whether an employee would leave. The XG Boost model's default salary level is high.

# %% [markdown]
# # pacE: Execute Stage
# - Interpret model performance and results
# - Share actionable steps with stakeholders

# %% [markdown]
# ✏
# ## Recall evaluation metrics
#
# - **AUC** is the area under the ROC curve; it's also considered the probability that the model ranks a random positive example more highly than a random negative example.
# - **Precision** measures the proportion of data points predicted as True that are actually True, in other words, the proportion of positive predictions that are true positives.
# - **Recall** measures the proportion of data points that are predicted as True, out of all the data points that are actually True. In other words, it measures the proportion of positives that are correctly classified.
# - **Accuracy** measures the proportion of data points that are correctly classified.
# - **F1-score** is an aggregation of precision and recall.

# %% [markdown]
# 💭
# ### Reflect on these questions as you complete the executing stage.
#
# - What key insights emerged from your model(s)?
# - What business recommendations do you propose based on the models built?
# - What potential recommendations would you make to your manager/company?
# - Do you think your model could be improved? Why or why not? How?
# - Given what you know about the data and the models you were using, what other questions could you address for the team?
# - What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# - Do you have any ethical considerations in this stage?

# %% [markdown]
# Last evaluation, average monthly hours, satisfaction level, tenure, number of projects and salary are the important features, in that order. They are important variables to predict whether an employee would leave.
#
# The model has an accuracy score of 0.98065 and an f1 score of 0.939834, meaning that this model has a strong predictive power. The confusion matrix indicates that there are a small number of false positive and false negative, confirming the f1 score.
#
# The model can indentify the potential employee who could leave in the near future and notify the HR department. The model indicates that Last evaluation, average monthly hours, satisfaction level, tenure, number of projects and salary are the important features for the prediction and we discovered that overworked employees tend to leave the company. The HR department could implement preventive measures on those identified employees to enhance retention. The preventive measures could be reducing the number of projects that they are handling, their working hours or suggesting them to take a vacation.
#
# In addtion, we discovered that employees who worked in the company for more than 6 years were less likely to leave. The company could consider to provide long term service incentive to the employees to encourage them to stay with the company for more than 6 years.
#
# The model's predictive power is close to perfect when using the current predictive variables. It is noted that some variables may not be avaliable in certain situations. For example, satisfaction level may not be reliable or avaliable. We may build another model without using satisfaction level as a predictive variables. The new model could be used in more different senario.
#
# The data team can further investigate the data to indentify the factors that contribute to the employee satisfaction levels at the company. The company could then use the findings to enhance the overall employee satisfaction level.

# %% [markdown]
# ## Step 4. Results and Evaluation
# - Interpret model
# - Evaluate model performance using metrics
# - Prepare results, visualizations, and actionable steps to share with stakeholders

# %% [markdown]
# ### Summary of model results
#
# The model has an accuracy score of 0.98065 and an f1 score of 0.939834, meaning that this model has a strong predictive power. The confusion matrix indicates that there are a small number of false positive and false negative, confirming the f1 score.

# %% [markdown]
# ### Conclusion, Recommendations, Next Steps
#
# The model can indentify the potential employee who could leave in the near future and notify the HR department. The model indicates that Last evaluation, average monthly hours, satisfaction level, tenure, number of projects and salary are the important features for the prediction and we discovered that overworked employees tend to leave the company. The HR department could implement preventive measures on those identified employees to enhance retention. The preventive measures could be reducing the number of projects that they are handling, their working hours or suggesting them to take a vacation.
#
# In addtion, we discovered that employees who worked in the company for more than 6 years were less likely to leave. The company could consider to provide long term service incentive to the employees to encourage them to stay with the company for more than 6 years.
#
# The model's predictive power is close to perfect when using the current predictive variables. It is noted that some variables may not be avaliable in certain situations. For example, satisfaction level may not be reliable or avaliable. We may build another model without using satisfaction level as a predictive variables. The new model could be used in more different senario.

# %% [markdown]
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.
